# %% [markdown]
# Corrija o código de maneira que ele possa ser executado.
# Critério de correção: serão somados pontos para cada erro removido. A nota máxima será dada para as AC’s que removeram todos os erros e cujo código está rodando corretamente.
#
# Dica: Apenas uma saída precisa estar funcionando, alert() ou console.log.
#
# Dica: Teste seu código em mais de um navegador antes de entregar.
#
# Dica: A lógica do programa está correta.
#
# Dica: Apenas o html e o javascript possuem erros.
#
#
# ***O que o programa deve fazer:***
#
# Ele recebe uma string nome , se ela for vazia retorna uma mensagem de erro, senão retorna mensagem de sucesso.  Recebe uma string escola e verifica se ela está cadastrada, se não estiver retorna mensagem de erro, se estiver cadastrada retorna mensagem de sucesso. Recebe a idade em anos e retorna o ano de nascimento, se idade for inválida retorna mensagem de erro.

# %%
#Escreva aqui o nome do Navegador que você usou.
#

from IPython.display import display, HTML, Javascript

html ='''
<!DOCTYPE html>

<html lang="pt-br">

<head>
    <title>AC 5</title>

    <meta http-equiv="Content-Language" content="pt-br">
    <meta charset="utf-8" />
    <script>
        function verificaNome(nome) {

            if (nome.value == "") {

                alert("Nome não é valido.");
                console.log("invalido.");
                return false;

            }else{

            alert("Nome OK.");
            console.log("Nome OK.");
            return true;

        }
    }

        function verificaEscola(escola) {

            var listaEscolas = ["esc1", "esc2", "esc3", "esc4"];
            var esc = true;
            

            for (var i = 0; i < listaEscolas.length; i++) {

                if (escola.value == listaEscolas[i]) {

                    alert("Escola ok");
                    console.log("Escola ok");
                    return true;

                }else{

            alert("Escola não está na lista");
            console.log("Escola não está na lista");
            return false;

        }
    }
}

        function verificaIdade(idade) {

           
            var ano = 2018;
            var nascEm = 0;

            if (idade.value == "") return false;

            var valIdade = Number(idade.value);

            if (valIdade < 0) {

                alert("Não nasceu");
                console.log("Não nasceu");
                return false;

            }else if (valIdade > 120) {

                alert("Já morreu");
                console.log("Já morreu");
                return false;

            }else{
            

            nascEm = ano - valIdade;

            alert("Você nasceu em " + nascEm);
            console.log("Você nasceu em " + nascEm);
            return true;
            }

        }

        function enviar() {

            var nome = document.getElementById('nome');
            var escola = document.getElementById('escola');
            var idade = document.getElementById('idade');

            verificaNome(nome);
            verificaEscola(escola);
            verificaIdade(idade);

        }
    </script>

</head>

<body>

    <form onsubmit='javascript: return enviar()'>

        <label for="nome">Nome</label> <br>
        <input type="text" id="nome" > <br>

        <label for="escola">Escola</label> <br>
        <input type="text" id="escola"> <br>

        <label for="idade">Idade</label> <br>
        <input type="text" id="idade"> <br>

        <input type="submit" value="Enviar">

    </form>

</body>

</html>
'''
display(HTML(html))
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
#
# <head>
#     <title>AC 5</title>
#
#     <meta http-equiv="Content-Language" content="pt-br">
#     <meta charset="utf-8" />
#     <script>
#         function verificaNome(nome) {
#
#             if (nome.value == "") {
#
#                 alert("Nome não é valido.");
#                 console.log("invalido.");
#                 return false;
#
#             }else{
#
#             alert("Nome OK.");
#             console.log("Nome OK.");
#             return true;
#
#         }
#     }
#
#         function verificaEscola(escola) {
#
#             var listaEscolas = ["esc1", "esc2", "esc3", "esc4"];
#             var esc = true;
#
#
#             for (var i = 0; i < listaEscolas.length; i++) {
#
#                 if (escola.value == listaEscolas[i]) {
#
#                     alert("Escola ok");
#                     console.log("Escola ok");
#                     return true;
#
#                 }else{
#
# ...
